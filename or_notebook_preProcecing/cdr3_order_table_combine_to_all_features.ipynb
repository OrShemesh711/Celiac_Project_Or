# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dfalls2 = pd.read_table("dfALL_after_order_genes.csv",sep="\t")
dfalls2.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  CDR3_AA_ACIDIC  \
# 0           0             0               0        0.105263
# 1           1             1               1        0.071429
# 2           2             2               2        0.100000
# 3           3             3               3        0.117647
# 4           4             4               4        0.111111
#
#    CDR3_AA_ALIPHATIC  CDR3_AA_AROMATIC  CDR3_AA_BASIC  CDR3_AA_BULK  \
# 0           0.410526          0.315789       0.052632     15.510000
# 1           0.771429          0.142857       0.071429     13.752143
# 2           0.390000          0.300000       0.050000     14.960000
# 3           0.058824          0.470588       0.058824     15.103529
# ...

# %%
# change names to short names
dfALLs2 = dfalls2
dfALLs2["SUBJECT"] =dfALLs2["SUBJECT"].str.split('_genotyped',1).str[0]
dfALLs2["SUBJECT"] =dfALLs2["SUBJECT"].str.split('results').str[1]

# %%
#save file
import csv
dfALLs2.to_csv("dfALL_after_order_genes.csv",sep="\t",quoting=csv.QUOTE_NONE)

# %%
dfALLs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3003858 entries, 0 to 3003857
# Data columns (total 58 columns):
# Unnamed: 0            int64
# Unnamed: 0.1          int64
# Unnamed: 0.1.1        int64
# CDR3_AA_ACIDIC        float64
# CDR3_AA_ALIPHATIC     float64
# CDR3_AA_AROMATIC      float64
# CDR3_AA_BASIC         float64
# CDR3_AA_BULK          float64
# CDR3_AA_CHARGE        float64
# CDR3_AA_GRAVY         float64
# CDR3_AA_LENGTH        float64
# CDR3_AA_POLARITY      float64
# CLIN                  object
# CONSCOUNT             int64
# D_CALL                object
# D_GERM_LENGTH         float64
# D_GERM_START          float64
# D_SEQ_LENGTH          float64
# D_SEQ_START           float64
# FUNCTIONAL            bool
# INDELS                bool
# IN_FRAME              bool
# JUNCTION              object
# JUNCTION_LENGTH       int64
# J_CALL                object
# J_GERM_LENGTH         int64
# J_GERM_START          int64
# J_SEQ_LENGTH          int64
# ...

# %%
dfALLs2[]
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  CDR3_AA_ACIDIC  \
# 0                 0             0               0        0.105263
# 1                 1             1               1        0.071429
# 2                 2             2               2        0.100000
# 3                 3             3               3        0.117647
# 4                 4             4               4        0.111111
# 5                 5             5               5        0.090909
# 6                 6             6               6        0.090909
# 7                 7             7               7        0.250000
# 8                 8             8               8        0.166667
# 9                 9             9               9        0.142857
# 10               10            10              10        0.200000
# 11               11            11              11        0.090909
# 12               12            12              12        0.235294
# ...

# %% [markdown]
# ## take the subject and sex coulmns (save as 'subject_sex_coulmns')

# %%
# look on table for take the relevant coulmn name
cdr2_table = pd.read_csv('cdr_table.csv',sep='\t' ,quoting=csv.QUOTE_NONE)
cdr2_table.head()
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 CDR3_AA_ACIDIC     CDR3_AA_ACIDIC.1  \
# 0          NaN        NaN        NaN          count                 mean
# 1      SUBJECT       CLIN        SEX            NaN                  NaN
# 2  Biotech_045    Healthy          M        33896.0  0.13443431517890864
# 3  Biotech_050    Healthy          M        38946.0  0.13625393022503643
# 4  Biotech_064     Celiac          F        34263.0  0.13020907753584962
#
#       CDR3_AA_ACIDIC.2 CDR3_AA_ACIDIC.3     CDR3_AA_ACIDIC.4  \
# 0                  std              min                  25%
# 1                  NaN              NaN                  NaN
# 2  0.06728160642848176              0.0   0.0833333333333333
# 3   0.0668210278345017              0.0   0.0833333333333333
# 4  0.06549249565160271              0.0  0.08166666666666665
#
#     CDR3_AA_ACIDIC.5     CDR3_AA_ACIDIC.6        ...         CDR3_AA_LENGTH.6  \
# ...

# %%
subject_sex = cdr2_table.loc[:,{'Unnamed: 0','Unnamed: 2'}]
subject_sex.rename({'Unnamed: 0':'SUBJECT' ,'Unnamed: 2':'SEX' }, inplace = True,axis='columns')
subject_sex = subject_sex.drop(subject_sex.index[[0,1]])
subject_sex.head()
# Out:
#   SEX      SUBJECT
# 2   M  Biotech_045
# 3   M  Biotech_050
# 4   F  Biotech_064
# 5   M  Biotech_065
# 6   F  Biotech_067

# %%
# save file
import csv
subject_sex.to_csv('subject_sex_coulmns.csv',sep='\t')

# %% [markdown]
# ## create new cdr3 table with all 98 samples (save as 'cdr3_table_98')

# %%
per_Sample= dfALLs2.groupby(['SAMPLE','CLIN']).describe()
per_Sample
# Out:
#                     CDR3_AA_ACIDIC                                     \
#                              count      mean       std  min       25%
# SAMPLE      CLIN
# BC_10       Healthy        39214.0  0.127038  0.065778  0.0  0.076923
# BC_11       Healthy        51925.0  0.133429  0.066271  0.0  0.083333
# BC_12       Healthy        40211.0  0.123196  0.065107  0.0  0.071429
# BC_13       Healthy        68761.0  0.131622  0.066742  0.0  0.076923
# BC_14       Healthy        56184.0  0.132791  0.066630  0.0  0.083333
# BC_16       Healthy        51619.0  0.132212  0.067483  0.0  0.076923
# BC_17       Healthy        42079.0  0.132310  0.067730  0.0  0.076923
# BC_18       Healthy        50719.0  0.133303  0.067200  0.0  0.083333
# Biotech_045 Healthy        33896.0  0.134434  0.067282  0.0  0.083333
# Biotech_050 Healthy        38946.0  0.136254  0.066821  0.0  0.083333
# Biotech_064 Celiac         34263.0  0.130209  0.065492  0.0  0.081667
# ...

# %%
cdr=per_Sample.loc[:,'CDR3_AA_ACIDIC':'CDR3_AA_POLARITY']
cdr
# Out:
#                     CDR3_AA_ACIDIC                                     \
#                              count      mean       std  min       25%
# SAMPLE      CLIN
# BC_10       Healthy        39214.0  0.127038  0.065778  0.0  0.076923
# BC_11       Healthy        51925.0  0.133429  0.066271  0.0  0.083333
# BC_12       Healthy        40211.0  0.123196  0.065107  0.0  0.071429
# BC_13       Healthy        68761.0  0.131622  0.066742  0.0  0.076923
# BC_14       Healthy        56184.0  0.132791  0.066630  0.0  0.083333
# BC_16       Healthy        51619.0  0.132212  0.067483  0.0  0.076923
# BC_17       Healthy        42079.0  0.132310  0.067730  0.0  0.076923
# BC_18       Healthy        50719.0  0.133303  0.067200  0.0  0.083333
# Biotech_045 Healthy        33896.0  0.134434  0.067282  0.0  0.083333
# Biotech_050 Healthy        38946.0  0.136254  0.066821  0.0  0.083333
# Biotech_064 Celiac         34263.0  0.130209  0.065492  0.0  0.081667
# ...

# %%
# SAVE FILE
cdr.to_csv('cdr3_table_98.csv',sep='\t')

# %% [markdown]
# ## create cdr3 per v_call and order it

# %%
cdr_v = dfALLs2.groupby(['SAMPLE','CLIN','V_CALL']).describe()
cdr_v
# Out:
#                                                           CDR3_AA_ACIDIC  \
#                                                                    count
# SAMPLE   CLIN    V_CALL
# BC_10    Healthy IGHV1-18*01                                      1475.0
#                  IGHV1-18*01,IGHV1-2*04                              1.0
#                  IGHV1-2*04                                        337.0
#                  IGHV1-24*01                                       294.0
#                  IGHV1-3*01                                        829.0
#                  IGHV1-45*02                                         3.0
#                  IGHV1-46*01                                       815.0
#                  IGHV1-46*01,IGHV1-69*01,IGHV1-69*06                 4.0
#                  IGHV1-58*01                                       112.0
#                  IGHV1-69*01                                      1974.0
# ...

# %%
cdr_vv=cdr_v.loc[:,'CDR3_AA_ACIDIC':'CDR3_AA_POLARITY']
cdr_vv.head()
# Out:
#                                       CDR3_AA_ACIDIC                      \
#                                                count      mean       std
# SAMPLE CLIN    V_CALL
# BC_10  Healthy IGHV1-18*01                    1475.0  0.132528  0.063642
#                IGHV1-18*01,IGHV1-2*04            1.0  0.333333       NaN
#                IGHV1-2*04                      337.0  0.122302  0.060577
#                IGHV1-24*01                     294.0  0.116213  0.064013
#                IGHV1-3*01                      829.0  0.124598  0.065397
#
#                                                                                \
#                                             min       25%       50%       75%
# SAMPLE CLIN    V_CALL
# BC_10  Healthy IGHV1-18*01             0.000000  0.083333  0.125000  0.166667
#                IGHV1-18*01,IGHV1-2*04  0.333333  0.333333  0.333333  0.333333
#                IGHV1-2*04              0.000000  0.076923  0.117647  0.166667
# ...
