# %% [markdown]
# # Visualization for genes

# %% [markdown]
# ## import data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library  
import matplotlib.pyplot as plt

VG_df = pd.read_csv('VGn.csv')
DG_df = pd.read_csv('DGn.csv')
VFn_df = pd.read_csv('VFn.csv')
DFn_df = pd.read_csv('DFn.csv')
Jn_df = pd.read_csv('Jn.csv')
JLn_df = pd.read_csv('JLn.csv')


VG_df.head()
# Out:
#    Unnamed: 0                     V_FAMILY_GROUP_SAMP_SEX      FREQ  V_FAMILY  \
# 0           0  ('IGHV1-18', 'Celiac', 'F', 'Biotech_092')  0.040626  IGHV1-18
# 1           1       ('IGHV1-18', 'Celiac', 'F', 'CD1110')  0.038050  IGHV1-18
# 2           2       ('IGHV1-18', 'Celiac', 'F', 'CD1113')  0.036511  IGHV1-18
# 3           3       ('IGHV1-18', 'Celiac', 'F', 'CD1169')  0.032414  IGHV1-18
# 4           4       ('IGHV1-18', 'Celiac', 'F', 'CD1205')  0.030685  IGHV1-18
#
#     GROUP SEX         SAMP
# 0  Celiac   F  Biotech_092
# 1  Celiac   F       CD1110
# 2  Celiac   F       CD1113
# 3  Celiac   F       CD1169
# 4  Celiac   F       CD1205

# %%
df=pd.read_csv('ALL_98samples.csv')
dfALLs = df
# split for new comportable coulmns
dfALLs['V_GENE'] = dfALLs['V_CALL'].str.split('*',1).str[0]
dfALLs['V_ALLELE']=dfALLs['V_CALL'].str.split(',',1).str[0]
dfALLs['V_FAMILY']=dfALLs['V_CALL'].str.split('-',1).str[0]

dfALLs['D_GENE'] = dfALLs['D_CALL'].str.split('*',1).str[0]
dfALLs['D_ALLELE']=dfALLs['D_CALL'].str.split(',',1).str[0]
dfALLs['D_FAMILY']=dfALLs['D_CALL'].str.split('-',1).str[0]

dfALLs['J_GENE'] = dfALLs['J_CALL'].str.split('*',1).str[0]
dfALLs['J_FAMILY']=dfALLs['J_CALL'].str.split('-',1).str[0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfALLs.head()
# Out:
#    Unnamed: 0  CDR3_AA_ACIDIC  CDR3_AA_ALIPHATIC  CDR3_AA_AROMATIC  \
# 0           0        0.105263           0.410526          0.315789
# 1           1        0.071429           0.771429          0.142857
# 2           2        0.100000           0.390000          0.300000
# 3           3        0.117647           0.058824          0.470588
# 4           4        0.111111           0.594444          0.277778
#
#    CDR3_AA_BASIC  CDR3_AA_BULK  CDR3_AA_CHARGE  CDR3_AA_GRAVY  CDR3_AA_LENGTH  \
# 0       0.052632     15.510000       -1.003173      -0.368421            19.0
# 1       0.071429     13.752143       -0.001683       0.414286            14.0
# 2       0.050000     14.960000       -1.007156      -0.440000            20.0
# 3       0.058824     15.103529       -1.007731      -0.900000            17.0
# 4       0.055556     15.718889       -1.009332       0.011111            18.0
#
#    CDR3_AA_POLARITY    ...    V_SEQ_LENGTH  V_SEQ_START    V_GENE  \
# 0          8.021053    ...             292            1  IGHV4-34
# 1          8.128571    ...             293            1  IGHV3-21
# 2          8.000000    ...             293            1  IGHV1-69
# 3          7.917647    ...             295            1  IGHV3-23
# 4          7.722222    ...             295            1  IGHV1-69
#
#       V_ALLELE  V_FAMILY    D_GENE     D_ALLELE  D_FAMILY  J_GENE  J_FAMILY
# 0  IGHV4-34*01     IGHV4  IGHD1-26  IGHD1-26*01     IGHD1   IGHJ5  IGHJ5*02
# 1  IGHV3-21*01     IGHV3  IGHD6-19  IGHD6-19*01     IGHD6   IGHJ4  IGHJ4*02
# 2  IGHV1-69*01     IGHV1   IGHD3-3   IGHD3-3*01     IGHD3   IGHJ6  IGHJ6*03
# 3  IGHV3-23*01     IGHV3   IGHD3-3   IGHD3-3*01     IGHD3   IGHJ5  IGHJ5*02
# 4  IGHV1-69*01     IGHV1  IGHD5-18  IGHD5-18*01     IGHD5   IGHJ6  IGHJ6*03
#
# [5 rows x 56 columns]

# %%
ch1 =dfALLs[dfALLs.J_FAMILY == 'IGHJ6*03']

# %%
ch2 = dfALLs[dfALLs.J_FAMILY == 'IGHJ6*02']

# %%
h =ch1.groupby('SAMPLE').D_GENE.unique()
h.sort_values(by=)
# Out:
# SAMPLE
# BC_10          [IGHD3-3, IGHD5-18, IGHD2-2, IGHD2-21, nan, IG...
# BC_17          [IGHD3-10, IGHD1-14, IGHD4-17, IGHD2/OR15-2a, ...
# Biotech_050    [IGHD6-6, IGHD2-15, IGHD3-22, IGHD5-12, IGHD3-...
# Biotech_065    [nan, IGHD2-2, IGHD3-3, IGHD1-7, IGHD2-15, IGH...
# Biotech_075    [IGHD4-17, IGHD6-13, IGHD2-15, IGHD6-25, IGHD5...
# Biotech_079    [nan, IGHD4-11, IGHD6-19, IGHD3-3, IGHD6-13, I...
# Biotech_086    [IGHD3-3, IGHD3-10, IGHD1-26, IGHD4-11, IGHD6-...
# Biotech_087    [IGHD3-10, IGHD1-26, IGHD3-3, IGHD1-14, IGHD6-...
# Biotech_089    [IGHD3-10, IGHD3-16, IGHD6-13, IGHD2-15, IGHD6...
# Biotech_092    [IGHD3-3, IGHD5-12, IGHD6-19, IGHD1-7, IGHD3-1...
# Biotech_094    [nan, IGHD1/OR15-1a, IGHD3-10, IGHD6-6, IGHD6-...
# Biotech_099    [IGHD1-14, IGHD2-15, IGHD1-26, IGHD3-10, IGHD5...
# Biotech_100    [IGHD3-10, IGHD4-17, IGHD6-13, IGHD4-23, IGHD2...
# Biotech_106    [IGHD3-10, IGHD2-2, IGHD1-1, IGHD3-16, IGHD4-1...
# Biotech_107    [IGHD5-12, IGHD3-10, IGHD7-27, IGHD5-24, IGHD3...
# Biotech_108    [IGHD3-3, IGHD4-17, IGHD3-22, IGHD3-16, IGHD5-...
# Biotech_111    [IGHD3-9, IGHD1-1, IGHD2/OR15-2a, IGHD3-3, IGH...
# Biotech_121    [IGHD3-22, IGHD3-10, IGHD6-6, IGHD2-2, IGHD2-8...
# Biotech_127    [IGHD1-26, IGHD2-2, IGHD1-1, IGHD3-10, IGHD3-3...
# Biotech_131    [IGHD6-6, IGHD3-3, IGHD2-2, IGHD3-10, IGHD5-12...
# CD0838         [IGHD3-3, IGHD2-2, IGHD6-6, IGHD6-13, IGHD2-15...
# CD1081         [IGHD3-9, IGHD6-19, IGHD3-10, IGHD2-2, IGHD2-1...
# HC_21_BB       [IGHD1-26, IGHD6-13, IGHD3-10, IGHD5-12, IGHD3...
# HC_22_BB       [IGHD1-1, IGHD4-23, IGHD6-13, IGHD3-9, IGHD4-1...
# HC_23_BB       [IGHD1-14, IGHD5-18, IGHD4-17, IGHD2-8, IGHD3-...
# HC_24_BB       [IGHD4-17, IGHD3-16, IGHD7-27, IGHD3-3, IGHD3-...
# HC_30_BB       [nan, IGHD2-2, IGHD2-15, IGHD4-23, IGHD1-26, I...
# HC_31_BB       [IGHD6-19, IGHD1-7, IGHD2-2, IGHD1-14, IGHD3-1...
# HC_32_BB       [IGHD2-15, IGHD3-3, IGHD2-2, IGHD4-11, IGHD3-1...
# HC_33_BB       [IGHD6-19, IGHD3-3, IGHD6-6, IGHD3-9, IGHD5-18...
# HC_34_BB       [IGHD2-2, IGHD3-3, IGHD3-10, IGHD6-13, IGHD6-6...
# HC_35_BB       [IGHD3-16, IGHD3-22, IGHD2-21, IGHD4-23, IGHD5...
# HC_36_BB       [IGHD1-14, IGHD5-18, IGHD6-6, IGHD5-12, IGHD3-...
# HC_37_BB       [IGHD3-3, IGHD2-2, IGHD2-15, IGHD2-21, IGHD1-2...
# HC_38_BB       [IGHD3-9, IGHD3-10, IGHD2-2, IGHD1-26, IGHD3-2...
# Name: D_GENE, Length: 93, dtype: object

# %%
group = ch1.groupby('SAMPLE').D_GENE.value_counts()
group
# Out:
# SAMPLE    D_GENE
# BC_10     IGHD3-10         888
#           IGHD3-3          879
#           IGHD2-2          861
#           IGHD6-13         723
#           IGHD6-6          534
#           IGHD1-26         505
#           IGHD2-15         466
#           IGHD6-19         463
#           IGHD4-17         438
#           IGHD3-22         432
#           IGHD5-18         425
#           IGHD3-16         264
#           IGHD5-12         249
#           IGHD4-11         214
#           IGHD3-9          213
#           IGHD1-1          207
#           IGHD1-7          169
#           IGHD2-8          169
#           IGHD2-21         151
#           IGHD5-24         151
#           IGHD4-23         115
#           IGHD1-14         114
#           IGHD7-27          92
#           IGHD2/OR15-2a     68
#           IGHD1-20          41
#           IGHD6-25          28
#           IGHD4/OR15-4a     23
#           IGHD5/OR15-5a     23
#           IGHD1/OR15-1a     14
#           IGHD3/OR15-3a     12
#                           ...
# HC_36_BB  IGHD5/OR15-5a      2
# HC_38_BB  IGHD2-2          492
#           IGHD3-3          326
#           IGHD3-10         112
#           IGHD2-15          79
#           IGHD4-11          72
#           IGHD6-13          67
#           IGHD6-6           51
#           IGHD5-18          49
#           IGHD6-19          47
#           IGHD3-16          41
#           IGHD1-1           36
#           IGHD4-17          33
#           IGHD3-9           30
#           IGHD2-8           26
#           IGHD5-12          26
#           IGHD1-14          23
#           IGHD2-21          17
#           IGHD1-26          16
#           IGHD3-22          13
#           IGHD2/OR15-2a     12
#           IGHD1-7           10
#           IGHD5-24           9
#           IGHD7-27           7
#           IGHD3/OR15-3a      5
#           IGHD6-25           5
#           IGHD1-20           3
#           IGHD1/OR15-1a      3
#           IGHD4-23           3
#           IGHD4/OR15-4a      1
# Name: D_GENE, Length: 1140, dtype: int64
